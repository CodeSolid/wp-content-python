# %%
import pandas as pd
df = pd.read_csv("TopPosts_9_19_2022_simplified.csv")
pd.set_option('display.max_rows', None)
df
# Out:
#                            Page title and screen class  Views
# 0    SymPy: Solving Math Equations in Python and Ju...   1375
# 1    How to Work With Google Sheets In Python and P...    622
# 2            CodeSolid.com - Python Learning Community    397
# 3    Python Indexing and Slicing: Complete Tutorial...    308
# 4    Pip vs Pipenv: Which is better and which to le...    275
# 5    How To Use Docker Python Images and Docker Com...    223
# 6    NumPy Examples — Practice Questions Make You a...    197
# 7    What Are pyc Files and __pycache__ folders In ...    168
# 8    Installing Pyenv on a Mac (A Setup Guide With ...    158
# 9    Pandas Examples and Review Questions to Make Y...    129
# 10          How To Profile Python Code - CodeSolid.com    120
# 11   Python String Examples: Tutorial and Practice ...    117
# 12   Python Dataclass: Easily Automate Class Best P...    115
# 13   Python Dunder Methods: The Ugliest Awesome Sau...    112
# ...

# %%
# %ls
# Out:
# LearnPythonLinks.txt              delme.txt
# README.md                         get_posts.py
# RecentTraffic_AsOf_9_18_2022      notes.md
# TopPostsAsOf_9_19_2022.csv        package-lock.json
# Untitled.ipynb                    package.json
# all_posts.csv                     posts.csv
# all_posts.json                    posts.json
# all_posts_ordered.json            posts.ods
# backup.tgz                        requirements.txt
# blog.ini                          venv/
# codesolid-content.code-workspace

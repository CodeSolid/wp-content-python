# %%
import pandas as pd
df = pd.read_csv("all_posts.csv", parse_dates=["date"])
print(type(df.iloc[0,2]))
print(df.iloc[0,2])
df.index = df.date
counts = df.groupby(pd.Grouper(freq="M")).count()
counts = counts[~(counts==0).all(axis=1)]
#counts
df
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2022-10-06 11:11:00
#                                                                  title  \
# date
# 2022-10-06 11:11:00                              Using LaTeX In Python
# 2022-09-29 10:45:00  Conda vs. Pip, Venv, and Pyenv &#8212; Simplic...
# 2022-09-22 09:48:00  Python Matrix Multiplication: NumPy, SymPy, an...
# 2022-09-20 08:04:15    Run Python Online: Watch the Video to Learn How
# 2022-09-14 16:59:00  Jupyter Lite:  Python in the Browser with Serv...
# ...                                                                ...
# 2021-03-21 12:25:00                              Node Starter Projects
# 2019-02-23 14:07:00         Fast S3 Updates with Golang and Goroutines
# 2018-07-05 11:10:00               Simple Vagrant Ansible Local Example
# 2013-07-04 13:29:00                           Using TestNG With Spring
# 2009-10-03 19:55:00                              DirectoryInfo Example
#
# ...

# %%
print(counts.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>url</th>
#       <th>date</th>
#       <th>categories</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-31</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2013-07-31</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2018-07-31</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2019-02-28</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2021-03-31</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
# ...
